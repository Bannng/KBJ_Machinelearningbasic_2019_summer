# %%
from google.colab import drive
drive. mount('/content/drive')
# %cd /content/drive/My Drive/Colab Notebooks/MachineLearning SummerSchool/data/rl

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

name_file ='./bank_of_america.csv'

columns = ['date','open','high','low','close','volume','adjclose']
data_in = pd.read_csv(name_file, names=columns, sep=',')

data_d = np.asarray(data_in['date'])[1:]
data_num = np.arange(0,len(data_d))

open_d = np.asarray(data_in['open'])[1:].astype(float)
high_d = np.asarray(data_in['high'])[1:].astype(float)
low_d = np.asarray(data_in['low'])[1:].astype(float)
close_d = np.asarray(data_in['close'])[1:].astype(float)
volume_d = np.asarray(data_in['volume'])[1:].astype(float)
adjclose_d = np.asarray(data_in['adjclose'])[1:].astype(float)

print(len(data_num)*0.7)
data_num_train = data_num[:878]
data_num_test = data_num[878:]

close_d_train = close_d[:878]
close_d_test = close_d[878:]

data_d, open_d
#data_num_train, data_num_test
